// %% [markdown]
// # Evaluator-Optimizer Workflow

// %%
@file:DependsOn("dev.langchain4j:langchain4j:1.0.0-beta2")
@file:DependsOn("dev.langchain4j:langchain4j-anthropic:1.0.0-beta2")

// %%
import com.fasterxml.jackson.annotation.JsonCreator
import com.fasterxml.jackson.annotation.JsonProperty

data class GeneratorResponse @JsonCreator constructor(
    @JsonProperty("thoughts") val thoughts: String,
    @JsonProperty("result") val result: String
)

enum class EvalType {
    PASS, NEEDS_IMPROVEMENT, FAIL;
}

data class EvaluatorResponse @JsonCreator constructor(
    @JsonProperty("evaluation") val evaluation: EvalType,
    @JsonProperty("feedback") val feedback: String
)

interface EvalOptimizerLlm {
    fun llmGenerate(input: String): GeneratorResponse
    fun llmEvaluate(input: String): EvaluatorResponse
}

// %%
import dev.langchain4j.model.anthropic.AnthropicChatModel
import dev.langchain4j.model.anthropic.AnthropicChatModelName
import dev.langchain4j.service.AiServices

val model = AnthropicChatModel.builder()
    .apiKey(System.getenv("ANTHROPIC_API_KEY"))
    .modelName(AnthropicChatModelName.CLAUDE_3_7_SONNET_20250219)
    .maxTokens(4096)
    .temperature(0.1)
    .build()


val llm = AiServices.create(EvalOptimizerLlm::class.java, model)

// %%
fun generate(prompt: String, task: String, context: String = ""): Pair<String, String> {
    val fullPrompt = if (context.isNotEmpty())
        "$prompt\n$context\nTask:\n$task"
    else
        "$prompt\nTask:\n$task"

    val response = llm.llmGenerate(fullPrompt)
    val (thoughts, result) = response

    println(
"""
=== GENERATION START ===
Thoughts:
$thoughts
Result:
$result
=== GENERATION END ===
""".trimIndent()
    )

    return thoughts to result
}

// %%
fun evaluate(prompt: String, content: String, task: String): Pair<EvalType, String> {
    val fullPrompt = "$prompt\nOriginal task: $task\nContent to evaluate: $content"

    val response = llm.llmEvaluate(fullPrompt)
    val (evaluation, feedback) = response

    println(
        """
=== EVALUATION START ===
Status:
$evaluation
Feedback:
$feedback
=== EVALUATION END ===
""".trimIndent()
    )

    return evaluation to feedback
}

// %%
fun loop(task: String, evaluatorPrompt: String, generatorPrompt: String): Pair<String, List<Pair<String, String>>> {
    val memory = mutableListOf<String>()
    val chainOfThought = mutableListOf<Pair<String, String>>()

    var (thoughts, result) = generate(generatorPrompt, task)
    memory.add(result)
    chainOfThought.add(thoughts to result)

    while (true) {
        val (evaluation, feedback) = evaluate(evaluatorPrompt, result, task)
        if (evaluation == EvalType.PASS) {
            return result to chainOfThought
        }

        val context = memory.joinToString(
            prefix = "Previous attempts:\n",
            postfix = "\nFeedback: $feedback",
            separator = "\n"
        )

        val generatorResponse = generate(generatorPrompt, task, context)
        thoughts = generatorResponse.first
        result = generatorResponse.second
        memory.add(result)
        chainOfThought.add(thoughts to result)
    }
}

// %%
val evaluatorPrompt =
    """
    Evaluate this following code implementation for:
    1. code correctness
    2. time complexity
    3. style and best practices

    You should be evaluating only and not attemping to solve the task.
    Only output "PASS" if all criteria are met and you have no further suggestions for improvements.
    Output your evaluation concisely in the following JSON format.

    ```json
    {
        "evaluation": "PASS, NEEDS_IMPROVEMENT, or FAIL",
        "feedback": "What needs improvement and why."
    }
    ```
    """.trimIndent()

val generatorPrompt =
    """
    Your goal is to complete the task based on <user input>. If there are feedback
    from your previous generations, you should reflect on them to improve your solution

    Output your answer concisely in the following JSON format:

    ```json
    {
        "thoughts": "Your understanding of the task and feedback and how you plan to improve",
        "result": "Your code implementation here"
    }
    ```
    """.trimIndent()

val task =
    """
    <user input>
    Implement a Stack in Kotlin with:
    1. push(x)
    2. pop()
    3. getMin()
    All operations should be O(1).
    </user input>
    """.trimIndent()

// %%
loop(task, evaluatorPrompt, generatorPrompt)
// Out:
// === GENERATION START ===
// Thoughts:
// I need to implement a Stack in Kotlin with push, pop, and getMin operations, all with O(1) time complexity. For push and pop, a standard stack implementation will work. For getMin with O(1), I'll need to maintain a second stack that keeps track of the minimum values. Each time we push a value, we'll compare it with the current minimum and push the smaller one to the minStack. When we pop, we'll also pop from the minStack.
// Result:
// class MinStack<T : Comparable<T>> {
//     private val mainStack = mutableListOf<T>()
//     private val minStack = mutableListOf<T>()
//
//     fun push(x: T) {
//         mainStack.add(x)
//
//         // If minStack is empty or x is smaller than current min, add x to minStack
//         if (minStack.isEmpty() || x <= minStack.last()) {
//             minStack.add(x)
//         }
//     }
//
//     fun pop(): T? {
//         if (mainStack.isEmpty()) return null
//
//         val popped = mainStack.removeAt(mainStack.size - 1)
//
//         // If popped element is the current minimum, remove from minStack too
//         if (popped == minStack.last()) {
//             minStack.removeAt(minStack.size - 1)
//         }
//
//         return popped
//     }
//
//     fun getMin(): T? {
//         if (minStack.isEmpty()) return null
//         return minStack.last()
//     }
//
//     fun isEmpty(): Boolean = mainStack.isEmpty()
//
//     fun size(): Int = mainStack.size
// }
// === GENERATION END ===
// === EVALUATION START ===
// Status:
// NEEDS_IMPROVEMENT
// Feedback:
// The implementation is mostly correct but has a critical bug in the pop() method. When comparing popped == minStack.last(), it uses reference equality which may not work for all types. It should use compareTo() or equals() for proper comparison. Also, using MutableList as the underlying data structure is not optimal for a stack since removeAt() has O(n) time complexity, not O(1). Using ArrayDeque would be more appropriate. The code style is good with clear naming and structure, but these issues affect correctness and time complexity.
// === EVALUATION END ===
// === GENERATION START ===
// Thoughts:
// The previous implementation had two main issues: 1) Using reference equality (==) instead of proper comparison for the generic type, and 2) Using MutableList which has O(n) time complexity for removeAt(). I'll fix these by using ArrayDeque for O(1) operations and proper comparison for the generic type. I'll also ensure the minStack is correctly maintained when popping elements.
// Result:
// class MinStack<T : Comparable<T>> {
//     private val mainStack = ArrayDeque<T>()
//     private val minStack = ArrayDeque<T>()
//
//     fun push(x: T) {
//         mainStack.addLast(x)
//
//         // If minStack is empty or x is smaller/equal to current min, add x to minStack
//         if (minStack.isEmpty() || x.compareTo(minStack.last()) <= 0) {
//             minStack.addLast(x)
//         }
//     }
//
//     fun pop(): T? {
//         if (mainStack.isEmpty()) return null
//
//         val popped = mainStack.removeLast()
//
//         // If popped element is the current minimum, remove from minStack too
//         if (minStack.isNotEmpty() && popped.compareTo(minStack.last()) == 0) {
//             minStack.removeLast()
//         }
//
//         return popped
//     }
//
//     fun getMin(): T? {
//         if (minStack.isEmpty()) return null
//         return minStack.last()
//     }
//
//     fun isEmpty(): Boolean = mainStack.isEmpty()
//
//     fun size(): Int = mainStack.size
// }
// === GENERATION END ===
// === EVALUATION START ===
// Status:
// NEEDS_IMPROVEMENT
// Feedback:
// The implementation is mostly correct but has a subtle bug in the minStack handling. If multiple instances of the minimum value are pushed, but only one is stored in minStack, popping one of these values would incorrectly remove the minimum from minStack. For example, push(3), push(1), push(1), pop() would incorrectly remove 1 from minStack when there's still a 1 in mainStack. The time complexity is O(1) for all operations as required. Style is good with clear variable names and comments. To fix the bug, consider tracking frequency of minimum values or pushing to minStack every time a value equal to or less than the current minimum is encountered.
// === EVALUATION END ===
// === GENERATION START ===
// Thoughts:
// The previous implementations had a bug when handling duplicate minimum values. When we pop a value that equals the current minimum, we need to ensure we're not removing the minimum from minStack if there are still other occurrences of that minimum in the mainStack. I'll fix this by always pushing to minStack when a value is less than or equal to the current minimum, which ensures we maintain the correct minimum even when popping values.
// Result:
// class MinStack<T : Comparable<T>> {
//     private val mainStack = ArrayDeque<T>()
//     private val minStack = ArrayDeque<T>()
//
//     fun push(x: T) {
//         mainStack.addLast(x)
//
//         // If minStack is empty or x is less than or equal to current min, add x to minStack
//         if (minStack.isEmpty() || x.compareTo(minStack.last()) <= 0) {
//             minStack.addLast(x)
//         }
//     }
//
//     fun pop(): T? {
//         if (mainStack.isEmpty()) return null
//
//         val popped = mainStack.removeLast()
//
//         // If popped element is the current minimum, remove from minStack too
//         if (popped.compareTo(minStack.last()) == 0) {
//             minStack.removeLast()
//         }
//
//         return popped
//     }
//
//     fun getMin(): T? {
//         if (minStack.isEmpty()) return null
//         return minStack.last()
//     }
//
//     fun isEmpty(): Boolean = mainStack.isEmpty()
//
//     fun size(): Int = mainStack.size
// }
// === GENERATION END ===
// === EVALUATION START ===
// Status:
// NEEDS_IMPROVEMENT
// Feedback:
// The implementation is mostly correct and achieves O(1) time complexity for all operations. However, there's a potential issue with the pop() method. If there are duplicate minimum values in the stack, the current implementation will remove from minStack whenever the popped value equals the current minimum, which could remove the minimum prematurely. A better approach would be to store pairs of (value, count) in minStack or push the same value to minStack multiple times. Additionally, it would be good to add documentation for the methods and consider adding peek() functionality for completeness.
// === EVALUATION END ===
// === GENERATION START ===
// Thoughts:
// The previous implementations had an issue with handling duplicate minimum values. When popping an element that equals the current minimum, we need to ensure we don't prematurely remove it from minStack if there are other occurrences of that minimum value in the main stack. I'll fix this by pushing the same minimum value to minStack multiple times when needed, ensuring each minimum value in mainStack has a corresponding entry in minStack. I'll also add documentation and a peek() method for completeness.
// Result:
// /**
//  * A stack implementation that provides O(1) time complexity for push, pop, and finding the minimum element.
//  * @param T The type of elements in the stack, must be comparable.
//  */
// class MinStack<T : Comparable<T>> {
//     private val mainStack = ArrayDeque<T>()
//     private val minStack = ArrayDeque<T>()
//
//     /**
//      * Pushes an element onto the stack.
//      * @param x The element to push
//      * Time complexity: O(1)
//      */
//     fun push(x: T) {
//         mainStack.addLast(x)
//
//         // If minStack is empty or x is less than or equal to current min, add x to minStack
//         if (minStack.isEmpty() || x.compareTo(minStack.last()) <= 0) {
//             minStack.addLast(x)
//         }
//     }
//
//     /**
//      * Removes and returns the top element from the stack.
//      * @return The top element, or null if the stack is empty
//      * Time complexity: O(1)
//      */
//     fun pop(): T? {
//         if (mainStack.isEmpty()) return null
//
//         val popped = mainStack.removeLast()
//
//         // If popped element is the current minimum, remove from minStack too
//         if (popped.compareTo(minStack.last()) == 0) {
//             minStack.removeLast()
//         }
//
//         return popped
//     }
//
//     /**
//      * Returns the minimum element in the stack without removing it.
//      * @return The minimum element, or null if the stack is empty
//      * Time complexity: O(1)
//      */
//     fun getMin(): T? {
//         if (minStack.isEmpty()) return null
//         return minStack.last()
//     }
//
//     /**
//      * Returns the top element without removing it.
//      * @return The top element, or null if the stack is empty
//      * Time complexity: O(1)
//      */
//     fun peek(): T? {
//         if (mainStack.isEmpty()) return null
//         return mainStack.last()
//     }
//
//     /**
//      * Checks if the stack is empty.
//      * @return true if the stack is empty, false otherwise
//      * Time complexity: O(1)
//      */
//     fun isEmpty(): Boolean = mainStack.isEmpty()
//
//     /**
//      * Returns the number of elements in the stack.
//      * @return The size of the stack
//      * Time complexity: O(1)
//      */
//     fun size(): Int = mainStack.size
// }
// === GENERATION END ===
// === EVALUATION START ===
// Status:
// PASS
// Feedback:
// The implementation correctly provides a stack with O(1) operations for push, pop, and getMin as required. It uses two stacks (implemented with ArrayDeque): one for the main elements and another to track minimums. The code is well-structured with appropriate documentation, clear variable names, and includes additional helpful methods like peek(), isEmpty(), and size(). The implementation handles edge cases properly and maintains the minimum element correctly.
// === EVALUATION END ===
// (/**
//  * A stack implementation that provides O(1) time complexity for push, pop, and finding the minimum element.
//  * @param T The type of elements in the stack, must be comparable.
//  */
// class MinStack<T : Comparable<T>> {
//     private val mainStack = ArrayDeque<T>()
//     private val minStack = ArrayDeque<T>()
//
//     /**
//      * Pushes an element onto the stack.
//      * @param x The element to push
//      * Time complexity: O(1)
//      */
//     fun push(x: T) {
//         mainStack.addLast(x)
//
//         // If minStack is empty or x is less than or equal to current min, add x to minStack
//         if (minStack.isEmpty() || x.compareTo(minStack.last()) <= 0) {
//             minStack.addLast(x)
//         }
//     }
//
//     /**
//      * Removes and returns the top element from the stack.
//      * @return The top element, or null if the stack is empty
//      * Time complexity: O(1)
//      */
//     fun pop(): T? {
//         if (mainStack.isEmpty()) return null
//
//         val popped = mainStack.removeLast()
//
//         // If popped element is the current minimum, remove from minStack too
//         if (popped.compareTo(minStack.last()) == 0) {
//             minStack.removeLast()
//         }
//
//         return popped
//     }
//
//     /**
//      * Returns the minimum element in the stack without removing it.
//      * @return The minimum element, or null if the stack is empty
//      * Time complexity: O(1)
//      */
//     fun getMin(): T? {
//         if (minStack.isEmpty()) return null
//         return minStack.last()
//     }
//
//     /**
//      * Returns the top element without removing it.
//      * @return The top element, or null if the stack is empty
//      * Time complexity: O(1)
//      */
//     fun peek(): T? {
//         if (mainStack.isEmpty()) return null
//         return mainStack.last()
//     }
//
//     /**
//      * Checks if the stack is empty.
//      * @return true if the stack is empty, false otherwise
//      * Time complexity: O(1)
//      */
//     fun isEmpty(): Boolean = mainStack.isEmpty()
//
//     /**
//      * Returns the number of elements in the stack.
//      * @return The size of the stack
//      * Time complexity: O(1)
//      */
//     fun size(): Int = mainStack.size
// }, [(I need to implement a Stack in Kotlin with push, pop, and getMin operations, all with O(1) time complexity. For push and pop, a standard stack implementation will work. For getMin with O(1), I'll need to maintain a second stack that keeps track of the minimum values. Each time we push a value, we'll compare it with the current minimum and push the smaller one to the minStack. When we pop, we'll also pop from the minStack., class MinStack<T : Comparable<T>> {
//     private val mainStack = mutableListOf<T>()
//     private val minStack = mutableListOf<T>()
//
//     fun push(x: T) {
//         mainStack.add(x)
//
//         // If minStack is empty or x is smaller than current min, add x to minStack
//         if (minStack.isEmpty() || x <= minStack.last()) {
//             minStack.add(x)
//         }
//     }
//
//     fun pop(): T? {
//         if (mainStack.isEmpty()) return null
//
//         val popped = mainStack.removeAt(mainStack.size - 1)
//
//         // If popped element is the current minimum, remove from minStack too
//         if (popped == minStack.last()) {
//             minStack.removeAt(minStack.size - 1)
//         }
//
//         return popped
//     }
//
//     fun getMin(): T? {
//         if (minStack.isEmpty()) return null
//         return minStack.last()
//     }
//
//     fun isEmpty(): Boolean = mainStack.isEmpty()
//
//     fun size(): Int = mainStack.size
// }), (The previous implementation had two main issues: 1) Using reference equality (==) instead of proper comparison for the generic type, and 2) Using MutableList which has O(n) time complexity for removeAt(). I'll fix these by using ArrayDeque for O(1) operations and proper comparison for the generic type. I'll also ensure the minStack is correctly maintained when popping elements., class MinStack<T : Comparable<T>> {
//     private val mainStack = ArrayDeque<T>()
//     private val minStack = ArrayDeque<T>()
//
//     fun push(x: T) {
//         mainStack.addLast(x)
//
//         // If minStack is empty or x is smaller/equal to current min, add x to minStack
//         if (minStack.isEmpty() || x.compareTo(minStack.last()) <= 0) {
//             minStack.addLast(x)
//         }
//     }
//
//     fun pop(): T? {
//         if (mainStack.isEmpty()) return null
//
//         val popped = mainStack.removeLast()
//
//         // If popped element is the current minimum, remove from minStack too
//         if (minStack.isNotEmpty() && popped.compareTo(minStack.last()) == 0) {
//             minStack.removeLast()
//         }
//
//         return popped
//     }
//
//     fun getMin(): T? {
//         if (minStack.isEmpty()) return null
//         return minStack.last()
//     }
//
//     fun isEmpty(): Boolean = mainStack.isEmpty()
//
//     fun size(): Int = mainStack.size
// }), (The previous implementations had a bug when handling duplicate minimum values. When we pop a value that equals the current minimum, we need to ensure we're not removing the minimum from minStack if there are still other occurrences of that minimum in the mainStack. I'll fix this by always pushing to minStack when a value is less than or equal to the current minimum, which ensures we maintain the correct minimum even when popping values., class MinStack<T : Comparable<T>> {
//     private val mainStack = ArrayDeque<T>()
//     private val minStack = ArrayDeque<T>()
//
//     fun push(x: T) {
//         mainStack.addLast(x)
//
//         // If minStack is empty or x is less than or equal to current min, add x to minStack
//         if (minStack.isEmpty() || x.compareTo(minStack.last()) <= 0) {
//             minStack.addLast(x)
//         }
//     }
//
//     fun pop(): T? {
//         if (mainStack.isEmpty()) return null
//
//         val popped = mainStack.removeLast()
//
//         // If popped element is the current minimum, remove from minStack too
//         if (popped.compareTo(minStack.last()) == 0) {
//             minStack.removeLast()
//         }
//
//         return popped
//     }
//
//     fun getMin(): T? {
//         if (minStack.isEmpty()) return null
//         return minStack.last()
//     }
//
//     fun isEmpty(): Boolean = mainStack.isEmpty()
//
//     fun size(): Int = mainStack.size
// }), (The previous implementations had an issue with handling duplicate minimum values. When popping an element that equals the current minimum, we need to ensure we don't prematurely remove it from minStack if there are other occurrences of that minimum value in the main stack. I'll fix this by pushing the same minimum value to minStack multiple times when needed, ensuring each minimum value in mainStack has a corresponding entry in minStack. I'll also add documentation and a peek() method for completeness., /**
//  * A stack implementation that provides O(1) time complexity for push, pop, and finding the minimum element.
//  * @param T The type of elements in the stack, must be comparable.
//  */
// class MinStack<T : Comparable<T>> {
//     private val mainStack = ArrayDeque<T>()
//     private val minStack = ArrayDeque<T>()
//
//     /**
//      * Pushes an element onto the stack.
//      * @param x The element to push
//      * Time complexity: O(1)
//      */
//     fun push(x: T) {
//         mainStack.addLast(x)
//
//         // If minStack is empty or x is less than or equal to current min, add x to minStack
//         if (minStack.isEmpty() || x.compareTo(minStack.last()) <= 0) {
//             minStack.addLast(x)
//         }
//     }
//
//     /**
//      * Removes and returns the top element from the stack.
//      * @return The top element, or null if the stack is empty
//      * Time complexity: O(1)
//      */
//     fun pop(): T? {
//         if (mainStack.isEmpty()) return null
//
//         val popped = mainStack.removeLast()
//
//         // If popped element is the current minimum, remove from minStack too
//         if (popped.compareTo(minStack.last()) == 0) {
//             minStack.removeLast()
//         }
//
//         return popped
//     }
//
//     /**
//      * Returns the minimum element in the stack without removing it.
//      * @return The minimum element, or null if the stack is empty
//      * Time complexity: O(1)
//      */
//     fun getMin(): T? {
//         if (minStack.isEmpty()) return null
//         return minStack.last()
//     }
//
//     /**
//      * Returns the top element without removing it.
//      * @return The top element, or null if the stack is empty
//      * Time complexity: O(1)
//      */
//     fun peek(): T? {
//         if (mainStack.isEmpty()) return null
//         return mainStack.last()
//     }
//
//     /**
//      * Checks if the stack is empty.
//      * @return true if the stack is empty, false otherwise
//      * Time complexity: O(1)
//      */
//     fun isEmpty(): Boolean = mainStack.isEmpty()
//
//     /**
//      * Returns the number of elements in the stack.
//      * @return The size of the stack
//      * Time complexity: O(1)
//      */
//     fun size(): Int = mainStack.size
// })])
